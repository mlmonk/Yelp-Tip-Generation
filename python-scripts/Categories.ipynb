# %%
import pandas as pd

# %%
tmp = pd.read_json('../data/categories.json')

# %%
tmp[tmp.title == 'Nightlife']
# Out:
#          alias country_blacklist country_whitelist parents      title
# 944  nightlife               NaN               NaN      []  Nightlife

# %%
main_categories = tmp[tmp.parents.apply(lambda x: True if len(x) == 0 else False)].title.to_list()

# %%
print(main_categories)
# Out:
# ['Active Life', 'Arts & Entertainment', 'Automotive', 'Beauty & Spas', 'Bicycles', 'Education', 'Event Planning & Services', 'Financial Services', 'Food', 'Health & Medical', 'Home Services', 'Hotels & Travel', 'Local Flavor', 'Local Services', 'Mass Media', 'Nightlife', 'Pets', 'Professional Services', 'Public Services & Government', 'Religious Organizations', 'Restaurants', 'Shopping']

# %%
tmp
# Out:
#                         alias  ...                             title
# 0                  3dprinting  ...                       3D Printing
# 1                   abruzzese  ...                         Abruzzese
# 2                absinthebars  ...                     Absinthe Bars
# 3                   acaibowls  ...                        Acai Bowls
# 4                 accessories  ...                       Accessories
# 5                 accountants  ...                       Accountants
# 6               acnetreatment  ...                    Acne Treatment
# 7                      active  ...                       Active Life
# 8                 acupuncture  ...                       Acupuncture
# 9           addictionmedicine  ...                Addiction Medicine
# 10           adoptionservices  ...                 Adoption Services
# 11                      adult  ...                             Adult
# 12                   adultedu  ...                   Adult Education
# ...
